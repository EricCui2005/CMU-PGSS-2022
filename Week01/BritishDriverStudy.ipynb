# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
df = pd.read_csv ("/gdrive/MyDrive/PGSS /Week 1/7 1 2022/britishSeatBeltStudy.csv")


df.columns = ['DriversKilled', 'Drivers', 'Front', 'Rear', 'kms', 'PetrolPrice', 'VanKilled', 'Law', 'Date']

df['Law'] = df['Law'].astype('category')

df['FractionOfDriversKilled'] = df['DriversKilled'] / df['Drivers']

df
# Out:
#      DriversKilled  Drivers  Front  Rear    kms  PetrolPrice  VanKilled Law  \
# 0              107     1687    867   269   9059     0.102972         12   0
# 1               97     1508    825   265   7685     0.102363          6   0
# 2              102     1507    806   319   9963     0.102062         12   0
# 3               87     1385    814   407  10955     0.100873          8   0
# 4              119     1632    991   454  11823     0.101020         10   0
# ..             ...      ...    ...   ...    ...          ...        ...  ..
# 187             96     1284    644   521  21626     0.114797          5   1
# 188            122     1444    643   429  20195     0.114093          7   1
# 189            120     1575    641   408  19928     0.116466          7   1
# 190            137     1737    711   490  18564     0.116026          4   1
# 191            154     1763    721   491  18149     0.116067          7   1
#
#            Date  FractionOfDriversKilled
# ...

# %%
df.plot.scatter(x = 'Date', y = 'FractionOfDriversKilled', c = 'Law', colormap = 'viridis')

# %%
df.plot.scatter(x = 'Date', y = 'DriversKilled', c = 'Law', colormap = 'viridis')

# %%
df.plot.scatter(x = 'kms', y = 'DriversKilled', c = 'Law', colormap = 'viridis')

# %%
df.plot.scatter(x = 'Date', y = 'kms', c = 'Law', colormap = 'viridis')

# %%
df.boxplot('kms', 'Law')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
df['Date'].describe()
# Out:
# count            192
# unique           192
# top       1969-01-01
# freq               1
# Name: Date, dtype: object

# %%
df.boxplot('DriversKilled', 'Law')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
df.groupby('Law').agg({'DriversKilled': ['min', 'max', 'std'], 'Drivers': ['min', 'max', 'mean', 'std'], 'Front': ['min', 'max', 'mean', 'std'], 'Rear': ['min', 'max', 'mean', 'std'], 'kms': ['min', 'max', 'mean', 'std'], 'PetrolPrice': ['min', 'max', 'mean', 'std'], 'VanKilled': ['min', 'max', 'mean', 'std'] })
# Out:
#     DriversKilled                 Drivers                                 \
#               min  max        std     min   max         mean         std
# Law
# 0              79  198  24.260876    1309  2654  1717.751479  266.891961
# 1              60  154  22.228600    1057  1763  1321.695652  199.723317
#
#     Front                    ...           kms              PetrolPrice  \
#       min   max        mean  ...          mean          std         min
# Law                          ...
# 0     567  1299  873.455621  ...  14463.295858  2663.173238    0.081179
# 1     426   721  570.956522  ...  18890.217391  1657.610574    0.113144
#
#                                   VanKilled
#           max      mean       std       min max      mean       std
# Law
# 0    0.133027  0.101874  0.011929         2  17  9.585799  3.500855
# 1    0.120059  0.116485  0.001968         2   8  5.173913  1.825381
#
# [2 rows x 27 columns]
